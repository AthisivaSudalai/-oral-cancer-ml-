# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/oral_cancer_prediction_dataset.csv')
print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %%
print(f'Shape of Dataset: {df.shape}')
# Out:
# Shape of Dataset: (84922, 25)

# %% [markdown]
# Shape of Dataset: (84922, 25)

# %%
print(df.columns.to_list())
# Out:
# ['ID', 'Country', 'Age', 'Gender', 'Tobacco Use', 'Alcohol Consumption', 'HPV Infection', 'Betel Quid Use', 'Chronic Sun Exposure', 'Poor Oral Hygiene', 'Diet (Fruits & Vegetables Intake)', 'Family History of Cancer', 'Compromised Immune System', 'Oral Lesions', 'Unexplained Bleeding', 'Difficulty Swallowing', 'White or Red Patches in Mouth', 'Tumor Size (cm)', 'Cancer Stage', 'Treatment Type', 'Survival Rate (5-Year, %)', 'Cost of Treatment (USD)', 'Economic Burden (Lost Workdays per Year)', 'Early Diagnosis', 'Oral Cancer (Diagnosis)']

# %% [markdown]
# ['ID', 'Country', 'Age', 'Gender', 'Tobacco Use', 'Alcohol Consumption', 'HPV Infection', 'Betel Quid Use', 'Chronic Sun Exposure', 'Poor Oral Hygiene', 'Diet (Fruits & Vegetables Intake)', 'Family History of Cancer', 'Compromised Immune System', 'Oral Lesions', 'Unexplained Bleeding', 'Difficulty Swallowing', 'White or Red Patches in Mouth', 'Tumor Size (cm)', 'Cancer Stage', 'Treatment Type', 'Survival Rate (5-Year, %)', 'Cost of Treatment (USD)', 'Economic Burden (Lost Workdays per Year)', 'Early Diagnosis', 'Oral Cancer (Diagnosis)']

# %%
df.head()
# Out:
#    ID       Country  Age  Gender Tobacco Use Alcohol Consumption  \
# 0   1         Italy   36  Female         Yes                 Yes
# 1   2         Japan   64    Male         Yes                 Yes
# 2   3            UK   37  Female          No                 Yes
# 3   4     Sri Lanka   55    Male         Yes                 Yes
# 4   5  South Africa   68    Male          No                  No
#
#   HPV Infection Betel Quid Use Chronic Sun Exposure Poor Oral Hygiene  ...  \
# 0           Yes             No                   No               Yes  ...
# 1           Yes             No                  Yes               Yes  ...
# 2            No             No                  Yes               Yes  ...
# 3            No            Yes                   No               Yes  ...
# 4            No             No                   No               Yes  ...
#
#   Difficulty Swallowing White or Red Patches in Mouth Tumor Size (cm)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 84922 entries, 0 to 84921
# Data columns (total 25 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   ID                                        84922 non-null  int64
#  1   Country                                   84922 non-null  str
#  2   Age                                       84922 non-null  int64
#  3   Gender                                    84922 non-null  str
#  4   Tobacco Use                               84922 non-null  str
#  5   Alcohol Consumption                       84922 non-null  str
#  6   HPV Infection                             84922 non-null  str
#  7   Betel Quid Use                            84922 non-null  str
#  8   Chronic Sun Exposure                      84922 non-null  str
#  9   Poor Oral Hygiene                         84922 non-null  str
# ...

# %% [markdown]
# <class 'pandas.DataFrame'>
# RangeIndex: 84922 entries, 0 to 84921
# Data columns (total 25 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   ID                                        84922 non-null  int64
#  1   Country                                   84922 non-null  str
#  2   Age                                       84922 non-null  int64
#  3   Gender                                    84922 non-null  str
#  4   Tobacco Use                               84922 non-null  str
#  5   Alcohol Consumption                       84922 non-null  str
#  6   HPV Infection                             84922 non-null  str
#  7   Betel Quid Use                            84922 non-null  str
#  8   Chronic Sun Exposure                      84922 non-null  str
#  9   Poor Oral Hygiene                         84922 non-null  str
#  10  Diet (Fruits & Vegetables Intake)         84922 non-null  str
#  11  Family History of Cancer                  84922 non-null  str
#  12  Compromised Immune System                 84922 non-null  str
#  13  Oral Lesions                              84922 non-null  str
#  14  Unexplained Bleeding                      84922 non-null  str
#  15  Difficulty Swallowing                     84922 non-null  str
#  16  White or Red Patches in Mouth             84922 non-null  str
#  17  Tumor Size (cm)                           84922 non-null  float64
#  18  Cancer Stage                              84922 non-null  int64
#  19  Treatment Type                            84922 non-null  str
# ...
#  23  Early Diagnosis                           84922 non-null  str
#  24  Oral Cancer (Diagnosis)                   84922 non-null  str
# dtypes: float64(3), int64(4), str(18)
# memory usage: 16.2 MB
# Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...

# %%
df.describe()
# Out:
#                  ID           Age  Tumor Size (cm)  Cancer Stage  \
# count  84922.000000  84922.000000     84922.000000  84922.000000
# mean   42461.500000     54.509444         1.747294      1.118756
# std    24515.014117     10.014839         2.028199      1.340418
# min        1.000000     15.000000         0.000000      0.000000
# 25%    21231.250000     48.000000         0.000000      0.000000
# 50%    42461.500000     55.000000         0.000000      0.000000
# 75%    63691.750000     61.000000         3.480075      2.000000
# max    84922.000000    101.000000         5.999899      4.000000
#
#        Survival Rate (5-Year, %)  Cost of Treatment (USD)  \
# count               84922.000000             84922.000000
# mean                   79.503364             39109.881244
# std                    26.483746             44710.687054
# min                    10.000750                 0.000000
# 25%                    65.233425                 0.000000
# ...

# %%
df.isnull().sum()
# Out:
# ID                                          0
# Country                                     0
# Age                                         0
# Gender                                      0
# Tobacco Use                                 0
# Alcohol Consumption                         0
# HPV Infection                               0
# Betel Quid Use                              0
# Chronic Sun Exposure                        0
# Poor Oral Hygiene                           0
# Diet (Fruits & Vegetables Intake)           0
# Family History of Cancer                    0
# Compromised Immune System                   0
# Oral Lesions                                0
# Unexplained Bleeding                        0
# Difficulty Swallowing                       0
# White or Red Patches in Mouth               0
# Tumor Size (cm)                             0
# Cancer Stage                                0
# Treatment Type                              0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Oral Cancer (Diagnosis)'].value_counts()
# Out:
# Oral Cancer (Diagnosis)
# No     42573
# Yes    42349
# Name: count, dtype: int64

# %%
df['Oral Cancer (Diagnosis)'].value_counts(normalize=True)*100
# Out:
# Oral Cancer (Diagnosis)
# No     50.131886
# Yes    49.868114
# Name: proportion, dtype: float64

# %%
df.dtypes
# Out:
# ID                                            int64
# Country                                         str
# Age                                           int64
# Gender                                          str
# Tobacco Use                                     str
# Alcohol Consumption                             str
# HPV Infection                                   str
# Betel Quid Use                                  str
# Chronic Sun Exposure                            str
# Poor Oral Hygiene                               str
# Diet (Fruits & Vegetables Intake)               str
# Family History of Cancer                        str
# Compromised Immune System                       str
# Oral Lesions                                    str
# Unexplained Bleeding                            str
# Difficulty Swallowing                           str
# White or Red Patches in Mouth                   str
# Tumor Size (cm)                             float64
# ...

# %%
categorical_cols = df.select_dtypes(include='object').columns.tolist()
for col in categorical_cols:
    print(f"\n{col}: {df[col].unique()}")
# Out:
# Country: <StringArray>
# [       'Italy',        'Japan',           'UK',    'Sri Lanka',
#  'South Africa',       'Taiwan',          'USA',      'Germany',
#        'France',    'Australia',       'Brazil',     'Pakistan',
#         'Kenya',       'Russia',      'Nigeria',        'Egypt',
#         'India']
# Length: 17, dtype: str
#
# Gender: <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str
#
# Tobacco Use: <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
#
# Alcohol Consumption: <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
#
# HPV Infection: <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
#
# Betel Quid Use: <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
#
# Chronic Sun Exposure: <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
#
# Poor Oral Hygiene: <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
#
# Diet (Fruits & Vegetables Intake): <StringArray>
# ['Low', 'High', 'Moderate']
# Length: 3, dtype: str
#
# ...

# %%
# Columns to drop
drop_cols = [
    'ID',
    'Tumor Size (cm)',
    'Cancer Stage',
    'Treatment Type',
    'Survival Rate (5-Year, %)',
    'Cost of Treatment (USD)',
    'Economic Burden (Lost Workdays per Year)',
    'Early Diagnosis'
]

# Check remaining columns after drop
remaining = [col for col in df.columns if col not in drop_cols]
print("Remaining columns:", remaining)
print("Total remaining:", len(remaining))
# Out:
# Remaining columns: ['Country', 'Age', 'Gender', 'Tobacco Use', 'Alcohol Consumption', 'HPV Infection', 'Betel Quid Use', 'Chronic Sun Exposure', 'Poor Oral Hygiene', 'Diet (Fruits & Vegetables Intake)', 'Family History of Cancer', 'Compromised Immune System', 'Oral Lesions', 'Unexplained Bleeding', 'Difficulty Swallowing', 'White or Red Patches in Mouth', 'Oral Cancer (Diagnosis)']
# Total remaining: 17
